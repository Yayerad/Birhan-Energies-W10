# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
data = pd.read_csv("../src/data/merged_data.csv")

# %%
# Convert date column to datetime
data["Date"] = pd.to_datetime(df["Date"])

# %%
# Handle missing values
data = data.interpolate(method='linear').dropna()

# %%
# Summary statistics
data.describe()
# Out:
#                                 Date        Price      GDP_USA  \
# count                           9139  9139.000000  9139.000000
# mean   2005-03-26 06:03:30.351241984    48.716183     3.015510
# min              1987-05-20 00:00:00     9.100000    -2.576500
# 25%              1996-05-08 12:00:00    19.130000     2.117830
# 50%              2005-03-28 00:00:00    39.660000     2.795606
# 75%              2014-02-24 12:00:00    70.640000     4.788425
# max              2025-03-01 00:00:00   143.950000     6.055053
# std                              NaN    32.915319     1.896840
#
#        Inflation_US_All  Inflation_US_Core      USD_EUR
# count       9139.000000        9139.000000  9139.000000
# mean         202.860725         210.069047     1.174946
# min          164.700000         175.600000     0.845500
# 25%          164.700000         175.600000     1.128700
# 50%          193.600000         200.200000     1.137100
# 75%          235.342000         236.625000     1.245200
# ...

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# Time series plots
fig, axes = plt.subplots(5, 1, figsize=(10, 15), sharex=True)

data["Price"].plot(ax=axes[0], title="Oil Price", color='blue')
data["GDP_USA"].plot(ax=axes[1], title="U.S. GDP Growth Rate", color='green')
data["Inflation_US_All"].plot(ax=axes[2], title="U.S. Inflation Rate (All Items)", color='red')
data["Inflation_US_Core"].plot(ax=axes[3], title="U.S. Inflation Rate (Core)", color='orange')
data["USD_EUR"].plot(ax=axes[4], title="USD to EUR Exchange Rate", color='purple')

plt.xlabel("Year")
plt.tight_layout()
plt.show()

# %%
# 3. Outlier Detection
# --------------------------
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title("Boxplot of Macroeconomic Indicators")
plt.xticks(rotation=45)
plt.show()
